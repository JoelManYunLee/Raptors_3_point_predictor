# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
year = '2024'
team_url = f"https://www.basketball-reference.com/teams/TOR/{year}.html"
df = pd.read_html(team_url)
roster = pd.DataFrame(df[0])
per_game = pd.DataFrame(df[1])
totals = pd.DataFrame(df[2])
advanced = pd.DataFrame(df[3])
roster
# Out:
#        No.                      Player Pos    Ht   Wt         Birth Date  \
# 0        4              Scottie Barnes  SG   6-7  227     August 1, 2001
# 1       33              Gary Trent Jr.  SG   6-5  209   January 18, 1999
# 2       25               Chris Boucher  PF   6-9  200   January 11, 1993
# 3       19                Jakob Poeltl   C   7-0  245   October 15, 1995
# 4        1                 Gradey Dick  SG   6-6  205  November 20, 2003
# 5        2             Jalen McDaniels  SF   6-9  205   January 31, 1998
# 6        5           Immanuel Quickley  PG   6-3  190      June 17, 1999
# 7        9                  RJ Barrett  SG   6-6  214      June 14, 2000
# 8   11, 34          Jontay Porter (TW)  PF  6-11  240  November 15, 1999
# 9       11                 Bruce Brown  PG   6-4  202    August 15, 1996
# 10      14              Garrett Temple  SG   6-5  195        May 8, 1986
# 11      13                Jordan Nwora  SF   6-8  225  September 9, 1998
# ...

# %%
schedule_url = "https://www.basketball-reference.com/teams/TOR/2024_games.html"
schedule = pd.read_html(schedule_url)[0]
df = pd.read_html(
  schedule_url,
  extract_links="body"
)[0]
schedule['boxscore'] = "https://www.basketball-reference.com" + df["Unnamed: 4"][0][1]
schedule.drop(columns=['Start (ET)', 'Unnamed: 3', 'Unnamed: 4', 'Notes'], inplace=True)
schedule
# Out:
#      G               Date Unnamed: 5                Opponent Unnamed: 7  \
# 0    1  Wed, Oct 25, 2023        NaN  Minnesota Timberwolves          W
# 1    2  Fri, Oct 27, 2023          @           Chicago Bulls          L
# 2    3  Sat, Oct 28, 2023        NaN      Philadelphia 76ers          L
# 3    4  Mon, Oct 30, 2023        NaN  Portland Trail Blazers          L
# 4    5   Wed, Nov 1, 2023        NaN         Milwaukee Bucks          W
# ..  ..                ...        ...                     ...        ...
# 81  79   Tue, Apr 9, 2024        NaN          Indiana Pacers        NaN
# 82  80  Wed, Apr 10, 2024          @           Brooklyn Nets        NaN
# 83   G               Date        NaN                Opponent        NaN
# 84  81  Fri, Apr 12, 2024          @              Miami Heat        NaN
# 85  82  Sun, Apr 14, 2024          @              Miami Heat        NaN
#
#    Unnamed: 8   Tm  Opp    W    L  Streak  \
# 0         NaN   97   94    1    0     W 1
# ...
