# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import commonallplayers

# Get team ID for the Toronto Raptors
team_dict = teams.get_teams()
raptors = [team for team in team_dict if team['abbreviation'] == 'TOR'][0]
raptors_id = raptors['id']

# %%
# Fetch all players for the Toronto Raptors
players = commonallplayers.CommonAllPlayers(is_only_current_season=1, league_id='00', season='2023-24')
players_df = players.get_data_frames()[0]

# Display the list of players
print("Players in the 2023-2024 NBA Season:")
print(players_df[['PERSON_ID', 'DISPLAY_FIRST_LAST']])
# Out:
# Players in the 2023-2024 NBA Season:
#      PERSON_ID DISPLAY_FIRST_LAST
# 0      1630173   Precious Achiuwa
# 1       203500       Steven Adams
# 2      1628389        Bam Adebayo
# 3      1630534       Ochai Agbaji
# 4      1630583       Santi Aldama
# ..         ...                ...
# 557     201152     Thaddeus Young
# 558    1629027         Trae Young
# 559    1630209     Omer Yurtseven
# 560     203469        Cody Zeller
# 561    1627826        Ivica Zubac
#
# [562 rows x 2 columns]

# %%
# Now Filter for NBA players on the raptors

raptors_players = players_df[players_df['TEAM_ID'] == raptors_id]

raptors_players.head(10)
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST     DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 3      1630534            Agbaji, Ochai           Ochai Agbaji             1
# 30     1630567          Barnes, Scottie         Scottie Barnes             1
# 31     1629628              Barrett, RJ             RJ Barrett             1
# 56     1628449           Boucher, Chris          Chris Boucher             1
# 67     1628971             Brown, Bruce            Bruce Brown             1
# 89     1630618             Carton, D.J.            D.J. Carton             1
# 126    1641711             Dick, Gradey            Gradey Dick             1
# 156    1631241   Freeman-Liberty, Javon  Javon Freeman-Liberty             1
# 328    1629667         McDaniels, Jalen        Jalen McDaniels             1
# 374    1641806         Nowell, Markquis        Markquis Nowell             1
#
#     FROM_YEAR TO_YEAR             PLAYERCODE            PLAYER_SLUG  \
# 3        2022    2023           ochai_agbaji           ochai_agbaji
# 30       2021    2023         scottie_barnes         scottie_barnes
# 31       2019    2023             rj_barrett             rj_barrett
# 56       2017    2023          chris_boucher          chris_boucher
# 67       2018    2023            bruce_brown            bruce_brown
# 89       2023    2023              dj_carton              dj_carton
# 126      2023    2023            gradey_dick            gradey_dick
# 156      2023    2023  javon_freeman-liberty  javon_freeman-liberty
# 328      2019    2023        jalen_mcdaniels        jalen_mcdaniels
# 374      2023    2023        markquis_nowell        markquis_nowell
#
#         TEAM_ID TEAM_CITY TEAM_NAME TEAM_ABBREVIATION TEAM_SLUG TEAM_CODE  \
# 3    1610612761   Toronto   Raptors               TOR   raptors   raptors
# 30   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 31   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 56   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 67   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 89   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 126  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 156  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 328  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 374  1610612761   Toronto   Raptors               TOR   raptors   raptors
#
#     GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 3                   Y                        00
# 30                  Y                        00
# 31                  Y                        00
# 56                  Y                        01
# 67                  Y                        01
# 89                  Y                        11
# 126                 Y                        11
# 156                 Y                        11
# 328                 Y                        01
# 374                 Y                        11

# %%
from nba_api.stats.endpoints import playerdashboardbyyearoveryear

def get_player_stats(player_id):
    # Fetch player stats for the current season
    player_stats = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id=player_id)
    player_stats_df = player_stats.get_data_frames()[1]  # Index 1 contains per game stats
    
    # Filter stats for the 2023-2024 season
    player_stats_2023_2024 = player_stats_df[player_stats_df['GROUP_VALUE'] == '2023-24']

    desired_statistics = ['MIN', 'GP', 'FG3_PCT', 'FG3M', 'FG3A', 'FG3_PCT_RANK', 'OREB', 'DREB', 'PLUS_MINUS']
    
    # Return the desired statistics
    return player_stats_2023_2024[desired_statistics]

# %%
# Print each player's 3 point goal percentage and their field goal percentage

raptors_stats = []
# Create an empty vector to store player names
player_names = []

for player_id in raptors_players['PERSON_ID']:
    player_info = raptors_players[raptors_players['PERSON_ID'] == player_id].iloc[0]
    player_name = player_info['DISPLAY_FIRST_LAST']

    player_stats = get_player_stats(player_id)

    print(f"\nPlayer: {player_name}")
    print(player_stats.iloc[0])

    player_names.extend([player_name])
    raptors_stats.append(player_stats.iloc[0])
# Out:
# Player: Ochai Agbaji
# MIN             1076.731667
# GP                56.000000
# FG3_PCT            0.331000
# FG3M              52.000000
# FG3A             157.000000
# FG3_PCT_RANK       1.000000
# OREB              39.000000
# DREB              95.000000
# PLUS_MINUS      -119.000000
# Name: 0, dtype: float64
#
# Player: Scottie Barnes
# MIN             2001.798333
# GP                57.000000
# FG3_PCT            0.350000
# FG3M              99.000000
# FG3A             283.000000
# FG3_PCT_RANK       1.000000
# OREB             133.000000
# DREB             332.000000
# PLUS_MINUS      -143.000000
# Name: 0, dtype: float64
#
# Player: RJ Barrett
# MIN             1435.396667
# GP                46.000000
# FG3_PCT            0.346000
# FG3M              71.000000
# FG3A             205.000000
# FG3_PCT_RANK       1.000000
# OREB              42.000000
# DREB             205.000000
# PLUS_MINUS       -95.000000
# Name: 0, dtype: float64
#
# Player: Chris Boucher
# MIN             644.945
# GP               47.000
# FG3_PCT           0.322
# FG3M             29.000
# FG3A             90.000
# FG3_PCT_RANK      4.000
# OREB             56.000
# DREB            132.000
# PLUS_MINUS       25.000
# Name: 0, dtype: float64
#
# Player: Bruce Brown
# MIN             1402.056667
# GP                49.000000
# FG3_PCT            0.316000
# FG3M              42.000000
# FG3A             133.000000
# FG3_PCT_RANK       1.000000
# OREB              40.000000
# DREB             180.000000
# PLUS_MINUS       -24.000000
# Name: 0, dtype: float64
#
# Player: D.J. Carton
# MIN             4.1
# GP              1.0
# FG3_PCT         0.0
# FG3M            0.0
# FG3A            0.0
# FG3_PCT_RANK    1.0
# OREB            0.0
# DREB            1.0
# PLUS_MINUS     -1.0
# Name: 0, dtype: float64
#
# Player: Gradey Dick
# MIN             557.923333
# GP               36.000000
# FG3_PCT           0.358000
# FG3M             38.000000
# FG3A            106.000000
# FG3_PCT_RANK      1.000000
# OREB             15.000000
# DREB             47.000000
# PLUS_MINUS     -108.000000
# Name: 0, dtype: float64
#
# Player: Javon Freeman-Liberty
# MIN             3.9
# GP              2.0
# FG3_PCT         0.0
# FG3M            0.0
# FG3A            0.0
# FG3_PCT_RANK    1.0
# OREB            1.0
# DREB            0.0
# PLUS_MINUS     -7.0
# Name: 0, dtype: float64
#
# Player: Jalen McDaniels
# MIN             299.230
# GP               34.000
# FG3_PCT           0.208
# FG3M             11.000
# FG3A             53.000
# FG3_PCT_RANK      6.000
# OREB              9.000
# DREB             33.000
# PLUS_MINUS      -50.000
# Name: 0, dtype: float64
#
# Player: Markquis Nowell
# MIN             3.516667
# GP              1.000000
# FG3_PCT         0.000000
# FG3M            0.000000
# FG3A            0.000000
# FG3_PCT_RANK    1.000000
# OREB            2.000000
# DREB            0.000000
# PLUS_MINUS      4.000000
# Name: 0, dtype: float64
#
# Player: Jordan Nwora
# MIN             325.111667
# GP               30.000000
# FG3_PCT           0.328000
# FG3M             20.000000
# FG3A             61.000000
# FG3_PCT_RANK      2.000000
# OREB             13.000000
# DREB             47.000000
# PLUS_MINUS      -46.000000
# Name: 0, dtype: float64
#
# Player: Kelly Olynyk
# MIN             1109.891667
# GP                55.000000
# FG3_PCT            0.404000
# FG3M              38.000000
# FG3A              94.000000
# FG3_PCT_RANK       1.000000
# OREB              69.000000
# DREB             207.000000
# PLUS_MINUS       -98.000000
# Name: 0, dtype: float64
#
# Player: Jakob Poeltl
# MIN             1228.653333
# GP                46.000000
# FG3_PCT            0.000000
# FG3M               0.000000
# FG3A               0.000000
# FG3_PCT_RANK       3.000000
# OREB             132.000000
# DREB             264.000000
# PLUS_MINUS       -29.000000
# Name: 0, dtype: float64
#
# Player: Jontay Porter
# MIN             220.786667
# GP               17.000000
# FG3_PCT           0.324000
# FG3M             12.000000
# FG3A             37.000000
# FG3_PCT_RANK      2.000000
# OREB             17.000000
# DREB             37.000000
# PLUS_MINUS      -61.000000
# Name: 0, dtype: float64
#
# Player: Immanuel Quickley
# MIN             1430.661667
# GP                52.000000
# FG3_PCT            0.411000
# FG3M             127.000000
# FG3A             309.000000
# FG3_PCT_RANK       1.000000
# OREB              13.000000
# DREB             156.000000
# PLUS_MINUS        43.000000
# Name: 0, dtype: float64
#
# Player: Garrett Temple
# MIN             68.876667
# GP              16.000000
# FG3_PCT          0.222000
# FG3M             2.000000
# FG3A             9.000000
# FG3_PCT_RANK    16.000000
# OREB             5.000000
# DREB             6.000000
# PLUS_MINUS     -10.000000
# Name: 0, dtype: float64
#
# Player: Gary Trent Jr.
# MIN             1378.753333
# GP                52.000000
# FG3_PCT            0.419000
# FG3M             126.000000
# FG3A             301.000000
# FG3_PCT_RANK       1.000000
# OREB              13.000000
# DREB             103.000000
# PLUS_MINUS       -93.000000
# Name: 0, dtype: float64

# %%
raptors_stats_df = pd.DataFrame(raptors_stats)

raptors_stats_df.insert(0, 'Player Name', player_names)

raptors_stats_df = raptors_stats_df.reset_index(drop=True)

raptors_stats_df.head(16)
# Out:
#               Player Name          MIN    GP  FG3_PCT   FG3M   FG3A  \
# 0            Ochai Agbaji  1076.731667  56.0    0.331   52.0  157.0
# 1          Scottie Barnes  2001.798333  57.0    0.350   99.0  283.0
# 2              RJ Barrett  1435.396667  46.0    0.346   71.0  205.0
# 3           Chris Boucher   644.945000  47.0    0.322   29.0   90.0
# 4             Bruce Brown  1402.056667  49.0    0.316   42.0  133.0
# 5             D.J. Carton     4.100000   1.0    0.000    0.0    0.0
# 6             Gradey Dick   557.923333  36.0    0.358   38.0  106.0
# 7   Javon Freeman-Liberty     3.900000   2.0    0.000    0.0    0.0
# 8         Jalen McDaniels   299.230000  34.0    0.208   11.0   53.0
# 9         Markquis Nowell     3.516667   1.0    0.000    0.0    0.0
# 10           Jordan Nwora   325.111667  30.0    0.328   20.0   61.0
# 11           Kelly Olynyk  1109.891667  55.0    0.404   38.0   94.0
# 12           Jakob Poeltl  1228.653333  46.0    0.000    0.0    0.0
# 13          Jontay Porter   220.786667  17.0    0.324   12.0   37.0
# 14      Immanuel Quickley  1430.661667  52.0    0.411  127.0  309.0
# 15         Garrett Temple    68.876667  16.0    0.222    2.0    9.0
# 16         Gary Trent Jr.  1378.753333  52.0    0.419  126.0  301.0
#
#     FG3_PCT_RANK   OREB   DREB  PLUS_MINUS
# 0            1.0   39.0   95.0      -119.0
# 1            1.0  133.0  332.0      -143.0
# 2            1.0   42.0  205.0       -95.0
# 3            4.0   56.0  132.0        25.0
# 4            1.0   40.0  180.0       -24.0
# 5            1.0    0.0    1.0        -1.0
# 6            1.0   15.0   47.0      -108.0
# 7            1.0    1.0    0.0        -7.0
# 8            6.0    9.0   33.0       -50.0
# 9            1.0    2.0    0.0         4.0
# 10           2.0   13.0   47.0       -46.0
# 11           1.0   69.0  207.0       -98.0
# 12           3.0  132.0  264.0       -29.0
# 13           2.0   17.0   37.0       -61.0
# 14           1.0   13.0  156.0        43.0
# 15          16.0    5.0    6.0       -10.0
# 16           1.0   13.0  103.0       -93.0

# %%
# Calculate the minutes played per game of each player
raptors_stats_df.insert(3, 'MPG', raptors_stats_df['MIN']/raptors_stats_df['GP'])
raptors_stats_df.insert(7, 'FG3APG', raptors_stats_df['FG3A']/raptors_stats_df['GP'])

raptors_stats_df.head(16)
# Out:
#               Player Name          MIN    GP        MPG  FG3_PCT   FG3M  \
# 0            Ochai Agbaji  1076.731667  56.0  19.227351    0.331   52.0
# 1          Scottie Barnes  2001.798333  57.0  35.119269    0.350   99.0
# 2              RJ Barrett  1435.396667  46.0  31.204275    0.346   71.0
# 3           Chris Boucher   644.945000  47.0  13.722234    0.322   29.0
# 4             Bruce Brown  1402.056667  49.0  28.613401    0.316   42.0
# 5             D.J. Carton     4.100000   1.0   4.100000    0.000    0.0
# 6             Gradey Dick   557.923333  36.0  15.497870    0.358   38.0
# 7   Javon Freeman-Liberty     3.900000   2.0   1.950000    0.000    0.0
# 8         Jalen McDaniels   299.230000  34.0   8.800882    0.208   11.0
# 9         Markquis Nowell     3.516667   1.0   3.516667    0.000    0.0
# 10           Jordan Nwora   325.111667  30.0  10.837056    0.328   20.0
# 11           Kelly Olynyk  1109.891667  55.0  20.179848    0.404   38.0
# 12           Jakob Poeltl  1228.653333  46.0  26.709855    0.000    0.0
# 13          Jontay Porter   220.786667  17.0  12.987451    0.324   12.0
# 14      Immanuel Quickley  1430.661667  52.0  27.512724    0.411  127.0
# 15         Garrett Temple    68.876667  16.0   4.304792    0.222    2.0
# 16         Gary Trent Jr.  1378.753333  52.0  26.514487    0.419  126.0
#
#      FG3A    FG3APG  FG3_PCT_RANK   OREB   DREB  PLUS_MINUS
# 0   157.0  2.803571           1.0   39.0   95.0      -119.0
# 1   283.0  4.964912           1.0  133.0  332.0      -143.0
# 2   205.0  4.456522           1.0   42.0  205.0       -95.0
# 3    90.0  1.914894           4.0   56.0  132.0        25.0
# 4   133.0  2.714286           1.0   40.0  180.0       -24.0
# 5     0.0  0.000000           1.0    0.0    1.0        -1.0
# 6   106.0  2.944444           1.0   15.0   47.0      -108.0
# 7     0.0  0.000000           1.0    1.0    0.0        -7.0
# 8    53.0  1.558824           6.0    9.0   33.0       -50.0
# 9     0.0  0.000000           1.0    2.0    0.0         4.0
# 10   61.0  2.033333           2.0   13.0   47.0       -46.0
# 11   94.0  1.709091           1.0   69.0  207.0       -98.0
# 12    0.0  0.000000           3.0  132.0  264.0       -29.0
# 13   37.0  2.176471           2.0   17.0   37.0       -61.0
# 14  309.0  5.942308           1.0   13.0  156.0        43.0
# 15    9.0  0.562500          16.0    5.0    6.0       -10.0
# 16  301.0  5.788462           1.0   13.0  103.0       -93.0
