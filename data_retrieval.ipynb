# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import commonallplayers

# Get team ID for the Toronto Raptors
team_dict = teams.get_teams()
raptors = [team for team in team_dict if team['abbreviation'] == 'TOR'][0]
raptors_id = raptors['id']

# %%
# Fetch all players for the Toronto Raptors
players = commonallplayers.CommonAllPlayers(is_only_current_season=1, league_id='00', season='2023-24')
players_df = players.get_data_frames()[0]

# Display the list of players
print("Players in the 2023-2024 NBA Season:")
print(players_df[['PERSON_ID', 'DISPLAY_FIRST_LAST']])
# Out:
# Players in the 2023-2024 NBA Season:
#      PERSON_ID DISPLAY_FIRST_LAST
# 0      1630173   Precious Achiuwa
# 1       203500       Steven Adams
# 2      1628389        Bam Adebayo
# 3      1630534       Ochai Agbaji
# 4      1630583       Santi Aldama
# ..         ...                ...
# 565     201152     Thaddeus Young
# 566    1629027         Trae Young
# 567    1630209     Omer Yurtseven
# 568     203469        Cody Zeller
# 569    1627826        Ivica Zubac
#
# [570 rows x 2 columns]

# %%
# Now Filter for NBA players on the raptors

raptors_players = players_df[players_df['TEAM_ID'] == raptors_id]

raptors_players.head(10)
# Out:
#      PERSON_ID DISPLAY_LAST_COMMA_FIRST     DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 3      1630534            Agbaji, Ochai           Ochai Agbaji             1
# 30     1630567          Barnes, Scottie         Scottie Barnes             1
# 31     1629628              Barrett, RJ             RJ Barrett             1
# 56     1628449           Boucher, Chris          Chris Boucher             1
# 68     1628971             Brown, Bruce            Bruce Brown             1
# 90     1630618             Carton, D.J.            D.J. Carton             1
# 127    1641711             Dick, Gradey            Gradey Dick             1
# 158    1631241   Freeman-Liberty, Javon  Javon Freeman-Liberty             1
# 194    1631338        Gueye, Mouhamadou       Mouhamadou Gueye             1
# 334    1629667         McDaniels, Jalen        Jalen McDaniels             1
#
#     FROM_YEAR TO_YEAR             PLAYERCODE            PLAYER_SLUG  \
# 3        2022    2023           ochai_agbaji           ochai_agbaji
# 30       2021    2023         scottie_barnes         scottie_barnes
# 31       2019    2023             rj_barrett             rj_barrett
# 56       2017    2023          chris_boucher          chris_boucher
# 68       2018    2023            bruce_brown            bruce_brown
# 90       2023    2023              dj_carton              dj_carton
# 127      2023    2023            gradey_dick            gradey_dick
# 158      2023    2023  javon_freeman-liberty  javon_freeman-liberty
# 194      2023    2023       mouhamadou_gueye       mouhamadou_gueye
# 334      2019    2023        jalen_mcdaniels        jalen_mcdaniels
#
#         TEAM_ID TEAM_CITY TEAM_NAME TEAM_ABBREVIATION TEAM_SLUG TEAM_CODE  \
# 3    1610612761   Toronto   Raptors               TOR   raptors   raptors
# 30   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 31   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 56   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 68   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 90   1610612761   Toronto   Raptors               TOR   raptors   raptors
# 127  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 158  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 194  1610612761   Toronto   Raptors               TOR   raptors   raptors
# 334  1610612761   Toronto   Raptors               TOR   raptors   raptors
#
#     GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 3                   Y                        00
# 30                  Y                        00
# 31                  Y                        00
# 56                  Y                        01
# 68                  Y                        01
# 90                  Y                        11
# 127                 Y                        11
# 158                 Y                        11
# 194                 Y                        11
# 334                 Y                        01

# %%
from nba_api.stats.endpoints import playerdashboardbyyearoveryear

def get_player_stats(player_id):
    # Fetch player stats for the current season
    player_stats = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id=player_id)
    player_stats_df = player_stats.get_data_frames()[1]  # Index 1 contains per game stats
    
    # Filter stats for the 2023-2024 season
    player_stats_2023_2024 = player_stats_df[player_stats_df['GROUP_VALUE'] == '2023-24']

    desired_statistics = ['MIN', 'GP', 'FG3_PCT', 'FG3M', 'FG3A', 'FG3_PCT_RANK', 'OREB', 'DREB', 'PLUS_MINUS']
    
    # Return the desired statistics
    return player_stats_2023_2024[desired_statistics]

# %%
# Print each player's 3 point goal percentage and their field goal percentage

raptors_stats = []
# Create an empty vector to store player names
player_names = []

for player_id in raptors_players['PERSON_ID']:
    player_info = raptors_players[raptors_players['PERSON_ID'] == player_id].iloc[0]
    player_name = player_info['DISPLAY_FIRST_LAST']

    player_stats = get_player_stats(player_id)

    print(f"\nPlayer: {player_name}")
    print(player_stats.iloc[0])

    player_names.extend([player_name])
    raptors_stats.append(player_stats.iloc[0])
# Out:
# Player: Ochai Agbaji
# MIN             1186.446667
# GP                62.000000
# FG3_PCT            0.318000
# FG3M              55.000000
# FG3A             173.000000
# FG3_PCT_RANK       1.000000
# OREB              46.000000
# DREB             108.000000
# PLUS_MINUS      -147.000000
# Name: 0, dtype: float64
#
# Player: Scottie Barnes
# MIN             2094.248333
# GP                60.000000
# FG3_PCT            0.341000
# FG3M             101.000000
# FG3A             296.000000
# FG3_PCT_RANK       1.000000
# OREB             141.000000
# DREB             353.000000
# PLUS_MINUS      -144.000000
# Name: 0, dtype: float64
#
# Player: RJ Barrett
# MIN             1637.965
# GP                52.000
# FG3_PCT            0.370
# FG3M              85.000
# FG3A             230.000
# FG3_PCT_RANK       1.000
# OREB              44.000
# DREB             228.000
# PLUS_MINUS      -117.000
# Name: 0, dtype: float64
#
# Player: Chris Boucher
# MIN             673.628333
# GP               49.000000
# FG3_PCT           0.319000
# FG3M             29.000000
# FG3A             91.000000
# FG3_PCT_RANK      5.000000
# OREB             61.000000
# DREB            138.000000
# PLUS_MINUS       25.000000
# Name: 0, dtype: float64
#
# Player: Bruce Brown
# MIN             1462.533333
# GP                52.000000
# FG3_PCT            0.304000
# FG3M              42.000000
# FG3A             138.000000
# FG3_PCT_RANK       1.000000
# OREB              43.000000
# DREB             188.000000
# PLUS_MINUS       -45.000000
# Name: 0, dtype: float64
#
# Player: D.J. Carton
# MIN             35.533333
# GP               4.000000
# FG3_PCT          0.250000
# FG3M             1.000000
# FG3A             4.000000
# FG3_PCT_RANK     1.000000
# OREB             2.000000
# DREB             2.000000
# PLUS_MINUS     -31.000000
# Name: 0, dtype: float64
#
# Player: Gradey Dick
# MIN             708.088333
# GP               42.000000
# FG3_PCT           0.374000
# FG3M             52.000000
# FG3A            139.000000
# FG3_PCT_RANK      1.000000
# OREB             19.000000
# DREB             61.000000
# PLUS_MINUS     -173.000000
# Name: 0, dtype: float64
#
# Player: Javon Freeman-Liberty
# MIN             40.533333
# GP               5.000000
# FG3_PCT          0.400000
# FG3M             2.000000
# FG3A             5.000000
# FG3_PCT_RANK     1.000000
# OREB             1.000000
# DREB             6.000000
# PLUS_MINUS     -15.000000
# Name: 0, dtype: float64
#
# Player: Mouhamadou Gueye
# MIN             9.683333
# GP              2.000000
# FG3_PCT         0.000000
# FG3M            0.000000
# FG3A            0.000000
# FG3_PCT_RANK    1.000000
# OREB            3.000000
# DREB            2.000000
# PLUS_MINUS      1.000000
# Name: 0, dtype: float64
#
# Player: Jalen McDaniels
# MIN             300.230
# GP               35.000
# FG3_PCT           0.204
# FG3M             11.000
# FG3A             54.000
# FG3_PCT_RANK      6.000
# OREB              9.000
# DREB             33.000
# PLUS_MINUS      -55.000
# Name: 0, dtype: float64
#
# Player: Jordan Nwora
# MIN             367.311667
# GP               34.000000
# FG3_PCT           0.310000
# FG3M             22.000000
# FG3A             71.000000
# FG3_PCT_RANK      2.000000
# OREB             17.000000
# DREB             53.000000
# PLUS_MINUS      -97.000000
# Name: 0, dtype: float64
#
# Player: Kelly Olynyk
# MIN             1261.645
# GP                61.000
# FG3_PCT            0.384
# FG3M              43.000
# FG3A             112.000
# FG3_PCT_RANK       1.000
# OREB              79.000
# DREB             223.000
# PLUS_MINUS      -141.000
# Name: 0, dtype: float64
#
# Player: Jakob Poeltl
# MIN             1319.108333
# GP                50.000000
# FG3_PCT            0.000000
# FG3M               0.000000
# FG3A               0.000000
# FG3_PCT_RANK       3.000000
# OREB             146.000000
# DREB             283.000000
# PLUS_MINUS       -17.000000
# Name: 0, dtype: float64
#
# Player: Jontay Porter
# MIN             244.320
# GP               19.000
# FG3_PCT           0.317
# FG3M             13.000
# FG3A             41.000
# FG3_PCT_RANK      2.000
# OREB             17.000
# DREB             41.000
# PLUS_MINUS      -81.000
# Name: 0, dtype: float64
#
# Player: Immanuel Quickley
# MIN             1647.995
# GP                58.000
# FG3_PCT            0.407
# FG3M             146.000
# FG3A             359.000
# FG3_PCT_RANK       1.000
# OREB              14.000
# DREB             194.000
# PLUS_MINUS        32.000
# Name: 0, dtype: float64
#
# Player: Jahmi'us Ramsey
# MIN             5.25
# GP              1.00
# FG3_PCT         0.00
# FG3M            0.00
# FG3A            1.00
# FG3_PCT_RANK    3.00
# OREB            1.00
# DREB            1.00
# PLUS_MINUS     -7.00
# Name: 0, dtype: float64
#
# Player: Garrett Temple
# MIN             68.876667
# GP              16.000000
# FG3_PCT          0.222000
# FG3M             2.000000
# FG3A             9.000000
# FG3_PCT_RANK    16.000000
# OREB             5.000000
# DREB             6.000000
# PLUS_MINUS     -10.000000
# Name: 0, dtype: float64
#
# Player: Gary Trent Jr.
# MIN             1571.720
# GP                58.000
# FG3_PCT            0.407
# FG3M             142.000
# FG3A             349.000
# FG3_PCT_RANK       2.000
# OREB              17.000
# DREB             122.000
# PLUS_MINUS       -95.000
# Name: 0, dtype: float64

# %%
raptors_stats_df = pd.DataFrame(raptors_stats)

raptors_stats_df.insert(0, 'Player Name', player_names)

raptors_stats_df = raptors_stats_df.reset_index(drop=True)

raptors_stats_df.head(16)
# Out:
#               Player Name          MIN    GP  FG3_PCT   FG3M   FG3A  \
# 0            Ochai Agbaji  1186.446667  62.0    0.318   55.0  173.0
# 1          Scottie Barnes  2094.248333  60.0    0.341  101.0  296.0
# 2              RJ Barrett  1637.965000  52.0    0.370   85.0  230.0
# 3           Chris Boucher   673.628333  49.0    0.319   29.0   91.0
# 4             Bruce Brown  1462.533333  52.0    0.304   42.0  138.0
# 5             D.J. Carton    35.533333   4.0    0.250    1.0    4.0
# 6             Gradey Dick   708.088333  42.0    0.374   52.0  139.0
# 7   Javon Freeman-Liberty    40.533333   5.0    0.400    2.0    5.0
# 8        Mouhamadou Gueye     9.683333   2.0    0.000    0.0    0.0
# 9         Jalen McDaniels   300.230000  35.0    0.204   11.0   54.0
# 10           Jordan Nwora   367.311667  34.0    0.310   22.0   71.0
# 11           Kelly Olynyk  1261.645000  61.0    0.384   43.0  112.0
# 12           Jakob Poeltl  1319.108333  50.0    0.000    0.0    0.0
# 13          Jontay Porter   244.320000  19.0    0.317   13.0   41.0
# 14      Immanuel Quickley  1647.995000  58.0    0.407  146.0  359.0
# 15        Jahmi'us Ramsey     5.250000   1.0    0.000    0.0    1.0
#
#     FG3_PCT_RANK   OREB   DREB  PLUS_MINUS
# 0            1.0   46.0  108.0      -147.0
# 1            1.0  141.0  353.0      -144.0
# 2            1.0   44.0  228.0      -117.0
# 3            5.0   61.0  138.0        25.0
# 4            1.0   43.0  188.0       -45.0
# 5            1.0    2.0    2.0       -31.0
# 6            1.0   19.0   61.0      -173.0
# 7            1.0    1.0    6.0       -15.0
# 8            1.0    3.0    2.0         1.0
# 9            6.0    9.0   33.0       -55.0
# 10           2.0   17.0   53.0       -97.0
# 11           1.0   79.0  223.0      -141.0
# 12           3.0  146.0  283.0       -17.0
# 13           2.0   17.0   41.0       -81.0
# 14           1.0   14.0  194.0        32.0
# 15           3.0    1.0    1.0        -7.0

# %%
# Calculate the minutes played per game of each player
raptors_stats_df.insert(3, 'MPG', raptors_stats_df['MIN']/raptors_stats_df['GP'])
raptors_stats_df.insert(7, 'FG3APG', raptors_stats_df['FG3A']/raptors_stats_df['GP'])

raptors_stats_df.head(16)
# Out:
#               Player Name          MIN    GP        MPG  FG3_PCT   FG3M  \
# 0            Ochai Agbaji  1186.446667  62.0  19.136237    0.318   55.0
# 1          Scottie Barnes  2094.248333  60.0  34.904139    0.341  101.0
# 2              RJ Barrett  1637.965000  52.0  31.499327    0.370   85.0
# 3           Chris Boucher   673.628333  49.0  13.747517    0.319   29.0
# 4             Bruce Brown  1462.533333  52.0  28.125641    0.304   42.0
# 5             D.J. Carton    35.533333   4.0   8.883333    0.250    1.0
# 6             Gradey Dick   708.088333  42.0  16.859246    0.374   52.0
# 7   Javon Freeman-Liberty    40.533333   5.0   8.106667    0.400    2.0
# 8        Mouhamadou Gueye     9.683333   2.0   4.841667    0.000    0.0
# 9         Jalen McDaniels   300.230000  35.0   8.578000    0.204   11.0
# 10           Jordan Nwora   367.311667  34.0  10.803284    0.310   22.0
# 11           Kelly Olynyk  1261.645000  61.0  20.682705    0.384   43.0
# 12           Jakob Poeltl  1319.108333  50.0  26.382167    0.000    0.0
# 13          Jontay Porter   244.320000  19.0  12.858947    0.317   13.0
# 14      Immanuel Quickley  1647.995000  58.0  28.413707    0.407  146.0
# 15        Jahmi'us Ramsey     5.250000   1.0   5.250000    0.000    0.0
#
#      FG3A    FG3APG  FG3_PCT_RANK   OREB   DREB  PLUS_MINUS
# 0   173.0  2.790323           1.0   46.0  108.0      -147.0
# 1   296.0  4.933333           1.0  141.0  353.0      -144.0
# 2   230.0  4.423077           1.0   44.0  228.0      -117.0
# 3    91.0  1.857143           5.0   61.0  138.0        25.0
# 4   138.0  2.653846           1.0   43.0  188.0       -45.0
# 5     4.0  1.000000           1.0    2.0    2.0       -31.0
# 6   139.0  3.309524           1.0   19.0   61.0      -173.0
# 7     5.0  1.000000           1.0    1.0    6.0       -15.0
# 8     0.0  0.000000           1.0    3.0    2.0         1.0
# 9    54.0  1.542857           6.0    9.0   33.0       -55.0
# 10   71.0  2.088235           2.0   17.0   53.0       -97.0
# 11  112.0  1.836066           1.0   79.0  223.0      -141.0
# 12    0.0  0.000000           3.0  146.0  283.0       -17.0
# 13   41.0  2.157895           2.0   17.0   41.0       -81.0
# 14  359.0  6.189655           1.0   14.0  194.0        32.0
# 15    1.0  1.000000           3.0    1.0    1.0        -7.0

# %%
# Export data as CSV
raptors_stats_df.to_csv('raptors_stats.csv', index=False)
